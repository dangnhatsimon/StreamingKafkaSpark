# %%
spark.stop()
# Out:
# 25/05/22 13:32:11 INFO  SparkContext:60 SparkContext is stopping with exitCode 0.
# 25/05/22 13:32:11 INFO  SparkUI:60 Stopped Spark web UI at http://6af08edc54fe:4040
# 25/05/22 13:32:07 INFO  StandaloneSchedulerBackend:60 Shutting down all executors
# 25/05/22 13:32:07 INFO  StandaloneSchedulerBackend$StandaloneDriverEndpoint:60 Asking each executor to shut down
# 25/05/22 13:32:07 INFO  MapOutputTrackerMasterEndpoint:60 MapOutputTrackerMasterEndpoint stopped!
# 25/05/22 13:32:07 INFO  MemoryStore:60 MemoryStore cleared
# 25/05/22 13:32:07 INFO  BlockManager:60 BlockManager stopped
# 25/05/22 13:32:07 INFO  BlockManagerMaster:60 BlockManagerMaster stopped
# 25/05/22 13:32:07 INFO  OutputCommitCoordinator$OutputCommitCoordinatorEndpoint:60 OutputCommitCoordinator stopped!
# 25/05/22 13:32:07 INFO  SparkContext:60 Successfully stopped SparkContext

# %%
# Create the Spark Session
from pyspark.sql import SparkSession

spark = (
    SparkSession 
    .builder 
    .appName("Streaming Process Files") 
    .config("spark.streaming.stopGracefullyOnShutdown", True) 
    .getOrCreate()
)

spark
# Out:
# 25/05/22 13:32:07 INFO  SparkContext:60 Running Spark version 3.5.5
# 25/05/22 13:32:07 INFO  SparkContext:60 OS info Linux, 5.15.167.4-microsoft-standard-WSL2, amd64
# 25/05/22 13:32:07 INFO  SparkContext:60 Java version 17.0.14
# Setting Spark log level to "INFO".
# 25/05/22 13:32:07 INFO  ResourceUtils:60 ==============================================================
# 25/05/22 13:32:07 INFO  ResourceUtils:60 No custom resources configured for spark.driver.
# 25/05/22 13:32:07 INFO  ResourceUtils:60 ==============================================================
# 25/05/22 13:32:07 INFO  SparkContext:60 Submitted application: Streaming Process Files
# 25/05/22 13:32:07 INFO  ResourceProfile:60 Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 4, script: , vendor: , memory -> name: memory, amount: 2048, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
# 25/05/22 13:32:07 INFO  ResourceProfile:60 Limiting resource is cpus at 4 tasks per executor
# 25/05/22 13:32:07 INFO  ResourceProfileManager:60 Added ResourceProfile id: 0
# 25/05/22 13:32:07 INFO  SecurityManager:60 Changing view acls to: root
# 25/05/22 13:32:07 INFO  SecurityManager:60 Changing modify acls to: root
# 25/05/22 13:32:07 INFO  SecurityManager:60 Changing view acls groups to:
# 25/05/22 13:32:07 INFO  SecurityManager:60 Changing modify acls groups to:
# 25/05/22 13:32:07 INFO  SecurityManager:60 SecurityManager: authentication disabled; ui acls disabled; users with view permissions: root; groups with view permissions: EMPTY; users with modify permissions: root; groups with modify permissions: EMPTY
# 25/05/22 13:32:07 INFO  Utils:60 Successfully started service 'sparkDriver' on port 34935.
# 25/05/22 13:32:07 INFO  SparkEnv:60 Registering MapOutputTracker
# 25/05/22 13:32:07 INFO  SparkEnv:60 Registering BlockManagerMaster
# 25/05/22 13:32:07 INFO  BlockManagerMasterEndpoint:60 Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 25/05/22 13:32:07 INFO  BlockManagerMasterEndpoint:60 BlockManagerMasterEndpoint up
# 25/05/22 13:32:07 INFO  SparkEnv:60 Registering BlockManagerMasterHeartbeat
# 25/05/22 13:32:07 INFO  DiskBlockManager:60 Created local directory at /tmp/blockmgr-6c262842-c304-4507-a46d-52fedf48cf96
# 25/05/22 13:32:07 INFO  MemoryStore:60 MemoryStore started with capacity 434.4 MiB
# 25/05/22 13:32:07 INFO  SparkEnv:60 Registering OutputCommitCoordinator
# 25/05/22 13:32:07 INFO  JettyUtils:60 Start Jetty 0.0.0.0:4040 for SparkUI
# 25/05/22 13:32:07 INFO  Utils:60 Successfully started service 'SparkUI' on port 4040.
# 25/05/22 13:32:07 INFO  StandaloneAppClient$ClientEndpoint:60 Connecting to master spark://kafka-streaming-spark-master:7077...
# 25/05/22 13:32:07 INFO  TransportClientFactory:316 Successfully created connection to kafka-streaming-spark-master/172.18.0.9:7077 after 1 ms (0 ms spent in bootstraps)
# 25/05/22 13:32:07 INFO  StandaloneSchedulerBackend:60 Connected to Spark cluster with app ID app-20250522133207-0008
# 25/05/22 13:32:07 INFO  StandaloneAppClient$ClientEndpoint:60 Executor added: app-20250522133207-0008/0 on worker-20250522132208-172.18.0.11-37935 (172.18.0.11:37935) with 4 core(s)
# 25/05/22 13:32:07 INFO  StandaloneSchedulerBackend:60 Granted executor ID app-20250522133207-0008/0 on hostPort 172.18.0.11:37935 with 4 core(s), 2.0 GiB RAM
# 25/05/22 13:32:07 INFO  Utils:60 Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 42885.
# 25/05/22 13:32:07 INFO  StandaloneAppClient$ClientEndpoint:60 Executor added: app-20250522133207-0008/1 on worker-20250522132208-172.18.0.13-33393 (172.18.0.13:33393) with 4 core(s)
# 25/05/22 13:32:07 INFO  NettyBlockTransferService:84 Server created on 6af08edc54fe:42885
# 25/05/22 13:32:07 INFO  BlockManager:60 Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 25/05/22 13:32:07 INFO  StandaloneSchedulerBackend:60 Granted executor ID app-20250522133207-0008/1 on hostPort 172.18.0.13:33393 with 4 core(s), 2.0 GiB RAM
# 25/05/22 13:32:07 INFO  StandaloneAppClient$ClientEndpoint:60 Executor added: app-20250522133207-0008/2 on worker-20250522132208-172.18.0.12-39507 (172.18.0.12:39507) with 4 core(s)
# 25/05/22 13:32:07 INFO  BlockManagerMaster:60 Registering BlockManager BlockManagerId(driver, 6af08edc54fe, 42885, None)
# 25/05/22 13:32:07 INFO  StandaloneSchedulerBackend:60 Granted executor ID app-20250522133207-0008/2 on hostPort 172.18.0.12:39507 with 4 core(s), 2.0 GiB RAM
# 25/05/22 13:32:07 INFO  BlockManagerMasterEndpoint:60 Registering block manager 6af08edc54fe:42885 with 434.4 MiB RAM, BlockManagerId(driver, 6af08edc54fe, 42885, None)
# 25/05/22 13:32:07 INFO  BlockManagerMaster:60 Registered BlockManager BlockManagerId(driver, 6af08edc54fe, 42885, None)
# 25/05/22 13:32:07 INFO  BlockManager:60 Initialized BlockManager: BlockManagerId(driver, 6af08edc54fe, 42885, None)
# 25/05/22 13:32:07 INFO  SingleEventLogFileWriter:60 Logging events to file:/opt/spark/spark-events/app-20250522133207-0008.inprogress
# 25/05/22 13:32:07 INFO  StandaloneAppClient$ClientEndpoint:60 Executor updated: app-20250522133207-0008/0 is now RUNNING
# 25/05/22 13:32:07 INFO  StandaloneAppClient$ClientEndpoint:60 Executor updated: app-20250522133207-0008/1 is now RUNNING
# 25/05/22 13:32:07 INFO  StandaloneAppClient$ClientEndpoint:60 Executor updated: app-20250522133207-0008/2 is now RUNNING
# 25/05/22 13:32:07 INFO  StandaloneSchedulerBackend:60 SchedulerBackend is ready for scheduling beginning after reached minRegisteredResourcesRatio: 0.0
# 25/05/22 13:32:07 INFO  SharedState:60 Setting hive.metastore.warehouse.dir ('/opt/spark/spark-warehouse/') to the value of spark.sql.warehouse.dir.
# 25/05/22 13:32:07 INFO  SharedState:60 Warehouse path is 'file:/opt/spark/spark-warehouse'.
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://6af08edc54fe:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://kafka-streaming-spark-master:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Streaming Process Files</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# To allow automatic schemaInference while reading
spark.conf.set("spark.sql.streaming.schemaInference", True)

# Create the streaming_df to read from input directory
streaming_df = (
    spark
    .readStream
    .option("cleanSource", "archive")
    .option("sourceArchiveDir", "/opt/spark/spark-archive")
    .option("maxFilesPerTrigger", 1)
    .format("json")
    .load("/opt/spark/datasets/devices/*.json")
)
# Out:
# 25/05/22 13:32:09 INFO  InMemoryFileIndex:60 It took 52 ms to list leaf files for 1 paths.
# 25/05/22 13:32:09 INFO  InMemoryFileIndex:60 It took 10 ms to list leaf files for 1 paths.
# 25/05/22 13:32:10 INFO  StandaloneSchedulerBackend$StandaloneDriverEndpoint:60 Registered executor NettyRpcEndpointRef(spark-client://Executor) (172.18.0.11:41004) with ID 0,  ResourceProfileId 0
# 25/05/22 13:32:10 INFO  StandaloneSchedulerBackend$StandaloneDriverEndpoint:60 Registered executor NettyRpcEndpointRef(spark-client://Executor) (172.18.0.13:54124) with ID 1,  ResourceProfileId 0
# 25/05/22 13:32:10 INFO  StandaloneSchedulerBackend$StandaloneDriverEndpoint:60 Registered executor NettyRpcEndpointRef(spark-client://Executor) (172.18.0.12:46236) with ID 2,  ResourceProfileId 0
# 25/05/22 13:32:10 INFO  BlockManagerMasterEndpoint:60 Registering block manager 172.18.0.11:33849 with 1048.8 MiB RAM, BlockManagerId(0, 172.18.0.11, 33849, None)
# 25/05/22 13:32:10 INFO  BlockManagerMasterEndpoint:60 Registering block manager 172.18.0.13:38223 with 1048.8 MiB RAM, BlockManagerId(1, 172.18.0.13, 38223, None)
# 25/05/22 13:32:10 INFO  BlockManagerMasterEndpoint:60 Registering block manager 172.18.0.12:40385 with 1048.8 MiB RAM, BlockManagerId(2, 172.18.0.12, 40385, None)
# 25/05/22 13:32:12 INFO  FileSourceStrategy:60 Pushed Filters:
# 25/05/22 13:32:12 INFO  FileSourceStrategy:60 Post-Scan Filters:
# 25/05/22 13:32:12 INFO  MemoryStore:60 Block broadcast_0 stored as values in memory (estimated size 202.7 KiB, free 434.2 MiB)
# 25/05/22 13:32:12 INFO  MemoryStore:60 Block broadcast_0_piece0 stored as bytes in memory (estimated size 35.2 KiB, free 434.2 MiB)
# 25/05/22 13:32:12 INFO  BlockManagerInfo:60 Added broadcast_0_piece0 in memory on 6af08edc54fe:42885 (size: 35.2 KiB, free: 434.4 MiB)
# 25/05/22 13:32:12 INFO  SparkContext:60 Created broadcast 0 from load at NativeMethodAccessorImpl.java:0
# 25/05/22 13:32:12 INFO  FileSourceScanExec:60 Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
# 25/05/22 13:32:12 INFO  SparkContext:60 Starting job: load at NativeMethodAccessorImpl.java:0
# 25/05/22 13:32:12 INFO  DAGScheduler:60 Got job 0 (load at NativeMethodAccessorImpl.java:0) with 1 output partitions
# 25/05/22 13:32:12 INFO  DAGScheduler:60 Final stage: ResultStage 0 (load at NativeMethodAccessorImpl.java:0)
# 25/05/22 13:32:12 INFO  DAGScheduler:60 Parents of final stage: List()
# 25/05/22 13:32:12 INFO  DAGScheduler:60 Missing parents: List()
# 25/05/22 13:32:12 INFO  DAGScheduler:60 Submitting ResultStage 0 (MapPartitionsRDD[3] at load at NativeMethodAccessorImpl.java:0), which has no missing parents
# 25/05/22 13:32:12 INFO  MemoryStore:60 Block broadcast_1 stored as values in memory (estimated size 17.0 KiB, free 434.2 MiB)
# 25/05/22 13:32:12 INFO  MemoryStore:60 Block broadcast_1_piece0 stored as bytes in memory (estimated size 8.0 KiB, free 434.1 MiB)
# 25/05/22 13:32:12 INFO  BlockManagerInfo:60 Added broadcast_1_piece0 in memory on 6af08edc54fe:42885 (size: 8.0 KiB, free: 434.4 MiB)
# 25/05/22 13:32:12 INFO  SparkContext:60 Created broadcast 1 from broadcast at DAGScheduler.scala:1585
# 25/05/22 13:32:12 INFO  DAGScheduler:60 Submitting 1 missing tasks from ResultStage 0 (MapPartitionsRDD[3] at load at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))
# 25/05/22 13:32:12 INFO  TaskSchedulerImpl:60 Adding task set 0.0 with 1 tasks resource profile 0
# 25/05/22 13:32:12 INFO  TaskSetManager:60 Starting task 0.0 in stage 0.0 (TID 0) (172.18.0.12, executor 2, partition 0, PROCESS_LOCAL, 9615 bytes)
# 25/05/22 13:32:12 INFO  BlockManagerInfo:60 Added broadcast_1_piece0 in memory on 172.18.0.12:40385 (size: 8.0 KiB, free: 1048.8 MiB)
# 25/05/22 13:32:13 INFO  BlockManagerInfo:60 Added broadcast_0_piece0 in memory on 172.18.0.12:40385 (size: 35.2 KiB, free: 1048.8 MiB)
# 25/05/22 13:32:13 INFO  TaskSetManager:60 Finished task 0.0 in stage 0.0 (TID 0) in 1242 ms on 172.18.0.12 (executor 2) (1/1)
# 25/05/22 13:32:13 INFO  TaskSchedulerImpl:60 Removed TaskSet 0.0, whose tasks have all completed, from pool
# 25/05/22 13:32:13 INFO  DAGScheduler:60 ResultStage 0 (load at NativeMethodAccessorImpl.java:0) finished in 1.342 s
# 25/05/22 13:32:13 INFO  DAGScheduler:60 Job 0 is finished. Cancelling potential speculative or zombie tasks for this job
# 25/05/22 13:32:13 INFO  TaskSchedulerImpl:60 Killing all running tasks in stage 0: Stage finished
# 25/05/22 13:32:13 INFO  DAGScheduler:60 Job 0 finished: load at NativeMethodAccessorImpl.java:0, took 1.386852 s

# %%
# To the schema of the data, place a sample json file and change readStream to read 
streaming_df.printSchema()
# streaming_df.show(truncate=False)
# Out:
# root
#  |-- customerId: string (nullable = true)
#  |-- data: struct (nullable = true)
#  |    |-- devices: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- deviceId: string (nullable = true)
#  |    |    |    |-- measure: string (nullable = true)
#  |    |    |    |-- status: string (nullable = true)
#  |    |    |    |-- temperature: long (nullable = true)
#  |-- eventId: string (nullable = true)
#  |-- eventOffset: long (nullable = true)
#  |-- eventPublisher: string (nullable = true)
#  |-- eventTime: string (nullable = true)

# %%
# Lets explode the data as devices contains list/array of device reading
from pyspark.sql.functions import explode

exploded_df = streaming_df.withColumn("data_devices", explode("data.devices"))

# %%
# Check the schema of the exploded_df, place a sample json file and change readStream to read 
exploded_df.printSchema()
#exploded_df.show(truncate=False)
# Out:
# root
#  |-- customerId: string (nullable = true)
#  |-- data: struct (nullable = true)
#  |    |-- devices: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- deviceId: string (nullable = true)
#  |    |    |    |-- measure: string (nullable = true)
#  |    |    |    |-- status: string (nullable = true)
#  |    |    |    |-- temperature: long (nullable = true)
#  |-- eventId: string (nullable = true)
#  |-- eventOffset: long (nullable = true)
#  |-- eventPublisher: string (nullable = true)
#  |-- eventTime: string (nullable = true)
#  |-- data_devices: struct (nullable = true)
#  |    |-- deviceId: string (nullable = true)
#  |    |-- measure: string (nullable = true)
#  |    |-- status: string (nullable = true)
#  |    |-- temperature: long (nullable = true)

# %%
# Flatten the exploded df
from pyspark.sql.functions import col

flattened_df = (
    exploded_df
    .drop("data")
    .withColumn("deviceId", col("data_devices.deviceId"))
    .withColumn("measure", col("data_devices.measure"))
    .withColumn("status", col("data_devices.status"))
    .withColumn("temperature", col("data_devices.temperature"))
    .drop("data_devices")
)

# %%
# Check the schema of the flattened_df, place a sample json file and change readStream to read 
flattened_df.printSchema()
#flattened_df.show(truncate=False)
# Out:
# root
#  |-- customerId: string (nullable = true)
#  |-- eventId: string (nullable = true)
#  |-- eventOffset: long (nullable = true)
#  |-- eventPublisher: string (nullable = true)
#  |-- eventTime: string (nullable = true)
#  |-- deviceId: string (nullable = true)
#  |-- measure: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- temperature: long (nullable = true)

# %%
# Write the output to console sink to check the output

(flattened_df
 .writeStream
 .format("csv")
 .outputMode("append")
 .option("path", "/opt/spark/datasets/output/device_data.csv")
 .option("checkpointLocation", "/opt/spark/spark-checkpoint")
 .start()
 .awaitTermination())
# Out:
# 25/05/22 13:32:14 INFO  BlockManagerInfo:60 Removed broadcast_0_piece0 on 6af08edc54fe:42885 in memory (size: 35.2 KiB, free: 434.4 MiB)
# 25/05/22 13:32:14 INFO  BlockManagerInfo:60 Removed broadcast_0_piece0 on 172.18.0.12:40385 in memory (size: 35.2 KiB, free: 1048.8 MiB)
# 25/05/22 13:32:14 INFO  BlockManagerInfo:60 Removed broadcast_1_piece0 on 6af08edc54fe:42885 in memory (size: 8.0 KiB, free: 434.4 MiB)
# 25/05/22 13:32:14 INFO  BlockManagerInfo:60 Removed broadcast_1_piece0 on 172.18.0.12:40385 in memory (size: 8.0 KiB, free: 1048.8 MiB)
# 25/05/22 13:32:14 INFO  StateStoreCoordinatorRef:60 Registered StateStoreCoordinator endpoint
# 25/05/22 13:32:14 INFO  ResolveWriteToStream:60 Checkpoint root /opt/spark/spark-checkpoint resolved to file:/opt/spark/spark-checkpoint.
# 25/05/22 13:32:14 WARN  ResolveWriteToStream:72 spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 25/05/22 13:32:14 INFO  CheckpointFileManager:60 Writing atomically to file:/opt/spark/spark-checkpoint/metadata using temp file file:/opt/spark/spark-checkpoint/.metadata.f1a6cc5b-bac3-49f6-8a4c-6c6a42671a38.tmp
# 25/05/22 13:32:14 INFO  CheckpointFileManager:60 Renamed temp file file:/opt/spark/spark-checkpoint/.metadata.f1a6cc5b-bac3-49f6-8a4c-6c6a42671a38.tmp to file:/opt/spark/spark-checkpoint/metadata
# 25/05/22 13:32:14 INFO  MicroBatchExecution:60 Starting [id = 917d27d6-db61-44ba-9bf3-c07d7bcbc499, runId = 182ce788-ca28-48a2-b2b5-1c5eea8b2279]. Use file:/opt/spark/spark-checkpoint to store the query checkpoint.
# 25/05/22 13:32:14 INFO  FileStreamSourceLog:60 Set the compact interval to 10 [defaultCompactInterval: 10]
# 25/05/22 13:32:14 INFO  FileStreamSourceLog:60 BatchIds found from listing:
# 25/05/22 13:32:14 INFO  FileStreamSourceLog:60 BatchIds found from listing:
# 25/05/22 13:32:14 INFO  FileStreamSource:60 maxFilesPerBatch = Some(1), maxFileAgeMs = 604800000
# 25/05/22 13:32:14 INFO  MicroBatchExecution:60 Using Source [FileStreamSource[file:/opt/spark/datasets/devices/*.json]] from DataSourceV1 named 'FileSource[/opt/spark/datasets/devices/*.json]' [DataSource(org.apache.spark.sql.SparkSession@8cadca4,json,List(),None,List(),None,Map(cleanSource -> archive, sourceArchiveDir -> /opt/spark/spark-archive, maxFilesPerTrigger -> 1, path -> /opt/spark/datasets/devices/*.json),None)]
# 25/05/22 13:32:14 INFO  OffsetSeqLog:60 BatchIds found from listing:
# 25/05/22 13:32:14 INFO  OffsetSeqLog:60 BatchIds found from listing:
# 25/05/22 13:32:14 INFO  MicroBatchExecution:60 Starting new streaming query.
# 25/05/22 13:32:14 INFO  MicroBatchExecution:60 Stream started from {}
# 25/05/22 13:32:14 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:14 INFO  CheckpointFileManager:60 Writing atomically to file:/opt/spark/spark-checkpoint/sources/0/0 using temp file file:/opt/spark/spark-checkpoint/sources/0/.0.a18f107a-0fe3-46c7-8ad1-c1451a6b0221.tmp
# 25/05/22 13:32:14 INFO  CheckpointFileManager:60 Renamed temp file file:/opt/spark/spark-checkpoint/sources/0/.0.a18f107a-0fe3-46c7-8ad1-c1451a6b0221.tmp to file:/opt/spark/spark-checkpoint/sources/0/0
# 25/05/22 13:32:14 INFO  FileStreamSource:60 Log offset set to 0 with 1 new files
# 25/05/22 13:32:14 INFO  CheckpointFileManager:60 Writing atomically to file:/opt/spark/spark-checkpoint/offsets/0 using temp file file:/opt/spark/spark-checkpoint/offsets/.0.5b6cd421-7ba9-488f-a63d-f1af4a47c944.tmp
# 25/05/22 13:32:14 INFO  CheckpointFileManager:60 Renamed temp file file:/opt/spark/spark-checkpoint/offsets/.0.5b6cd421-7ba9-488f-a63d-f1af4a47c944.tmp to file:/opt/spark/spark-checkpoint/offsets/0
# 25/05/22 13:32:14 INFO  MicroBatchExecution:60 Committed offsets for batch 0. Metadata OffsetSeqMetadata(0,1747920734863,Map(spark.sql.streaming.stateStore.providerClass -> org.apache.spark.sql.execution.streaming.state.HDFSBackedStateStoreProvider, spark.sql.streaming.join.stateFormatVersion -> 2, spark.sql.streaming.stateStore.compression.codec -> lz4, spark.sql.optimizer.pruneFiltersCanPruneStreamingSubplan -> false, spark.sql.streaming.stateStore.rocksdb.formatVersion -> 5, spark.sql.streaming.statefulOperator.useStrictDistribution -> true, spark.sql.streaming.flatMapGroupsWithState.stateFormatVersion -> 2, spark.sql.streaming.multipleWatermarkPolicy -> min, spark.sql.streaming.aggregation.stateFormatVersion -> 2, spark.sql.shuffle.partitions -> 200))
# 25/05/22 13:32:14 INFO  FileStreamSource:60 Processing 1 files from 0:0
# 25/05/22 13:32:15 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:15 INFO  FileSourceStrategy:60 Pushed Filters:
# 25/05/22 13:32:15 INFO  FileSourceStrategy:60 Post-Scan Filters:
# 25/05/22 13:32:15 INFO  FileSourceStrategy:60 Pushed Filters:
# 25/05/22 13:32:15 INFO  FileSourceStrategy:60 Post-Scan Filters:
# 25/05/22 13:32:15 INFO  FileStreamSinkLog:60 BatchIds found from listing:
# 25/05/22 13:32:15 INFO  CodeGenerator:60 Code generated in 216.288691 ms
# 25/05/22 13:32:15 INFO  MemoryStore:60 Block broadcast_2 stored as values in memory (estimated size 202.7 KiB, free 434.2 MiB)
# 25/05/22 13:32:15 INFO  MemoryStore:60 Block broadcast_2_piece0 stored as bytes in memory (estimated size 35.2 KiB, free 434.2 MiB)
# 25/05/22 13:32:15 INFO  BlockManagerInfo:60 Added broadcast_2_piece0 in memory on 6af08edc54fe:42885 (size: 35.2 KiB, free: 434.4 MiB)
# 25/05/22 13:32:15 INFO  SparkContext:60 Created broadcast 2 from start at NativeMethodAccessorImpl.java:0
# 25/05/22 13:32:15 INFO  FileSourceScanExec:60 Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
# 25/05/22 13:32:15 INFO  SparkContext:60 Starting job: start at NativeMethodAccessorImpl.java:0
# 25/05/22 13:32:15 INFO  DAGScheduler:60 Got job 1 (start at NativeMethodAccessorImpl.java:0) with 1 output partitions
# 25/05/22 13:32:15 INFO  DAGScheduler:60 Final stage: ResultStage 1 (start at NativeMethodAccessorImpl.java:0)
# 25/05/22 13:32:15 INFO  DAGScheduler:60 Parents of final stage: List()
# 25/05/22 13:32:15 INFO  DAGScheduler:60 Missing parents: List()
# 25/05/22 13:32:15 INFO  DAGScheduler:60 Submitting ResultStage 1 (MapPartitionsRDD[6] at start at NativeMethodAccessorImpl.java:0), which has no missing parents
# 25/05/22 13:32:15 INFO  MemoryStore:60 Block broadcast_3 stored as values in memory (estimated size 223.3 KiB, free 433.9 MiB)
# 25/05/22 13:32:15 INFO  MemoryStore:60 Block broadcast_3_piece0 stored as bytes in memory (estimated size 80.1 KiB, free 433.9 MiB)
# 25/05/22 13:32:15 INFO  BlockManagerInfo:60 Added broadcast_3_piece0 in memory on 6af08edc54fe:42885 (size: 80.1 KiB, free: 434.3 MiB)
# 25/05/22 13:32:15 INFO  SparkContext:60 Created broadcast 3 from broadcast at DAGScheduler.scala:1585
# 25/05/22 13:32:15 INFO  DAGScheduler:60 Submitting 1 missing tasks from ResultStage 1 (MapPartitionsRDD[6] at start at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))
# 25/05/22 13:32:15 INFO  TaskSchedulerImpl:60 Adding task set 1.0 with 1 tasks resource profile 0
# 25/05/22 13:32:15 INFO  TaskSetManager:60 Starting task 0.0 in stage 1.0 (TID 1) (172.18.0.11, executor 0, partition 0, PROCESS_LOCAL, 9615 bytes)
# 25/05/22 13:32:15 INFO  BlockManagerInfo:60 Added broadcast_3_piece0 in memory on 172.18.0.11:33849 (size: 80.1 KiB, free: 1048.7 MiB)
# 25/05/22 13:32:17 INFO  BlockManagerInfo:60 Added broadcast_2_piece0 in memory on 172.18.0.11:33849 (size: 35.2 KiB, free: 1048.7 MiB)
# 25/05/22 13:32:17 INFO  TaskSetManager:60 Finished task 0.0 in stage 1.0 (TID 1) in 1422 ms on 172.18.0.11 (executor 0) (1/1)
# 25/05/22 13:32:17 INFO  TaskSchedulerImpl:60 Removed TaskSet 1.0, whose tasks have all completed, from pool
# 25/05/22 13:32:17 INFO  DAGScheduler:60 ResultStage 1 (start at NativeMethodAccessorImpl.java:0) finished in 1.451 s
# 25/05/22 13:32:17 INFO  DAGScheduler:60 Job 1 is finished. Cancelling potential speculative or zombie tasks for this job
# 25/05/22 13:32:17 INFO  TaskSchedulerImpl:60 Killing all running tasks in stage 1: Stage finished
# 25/05/22 13:32:17 INFO  DAGScheduler:60 Job 1 finished: start at NativeMethodAccessorImpl.java:0, took 1.458043 s
# 25/05/22 13:32:17 INFO  FileFormatWriter:60 Start to commit write Job 79a70dec-c797-4f04-9e91-16028dad7172.
# 25/05/22 13:32:17 INFO  FileStreamSinkLog:60 Set the compact interval to 10 [defaultCompactInterval: 10]
# 25/05/22 13:32:17 INFO  CheckpointFileManager:60 Writing atomically to /opt/spark/datasets/output/device_data.csv/_spark_metadata/0 using temp file /opt/spark/datasets/output/device_data.csv/_spark_metadata/.0.fec9eccd-6dda-46f2-bd9a-0b875174122d.tmp
# 25/05/22 13:32:17 INFO  CheckpointFileManager:60 Renamed temp file /opt/spark/datasets/output/device_data.csv/_spark_metadata/.0.fec9eccd-6dda-46f2-bd9a-0b875174122d.tmp to /opt/spark/datasets/output/device_data.csv/_spark_metadata/0
# 25/05/22 13:32:17 INFO  ManifestFileCommitProtocol:60 Committed batch 0
# 25/05/22 13:32:17 INFO  FileFormatWriter:60 Write Job 79a70dec-c797-4f04-9e91-16028dad7172 committed. Elapsed time: 143 ms.
# 25/05/22 13:32:17 INFO  FileFormatWriter:60 Finished processing stats for write job 79a70dec-c797-4f04-9e91-16028dad7172.
# 25/05/22 13:32:17 INFO  CheckpointFileManager:60 Writing atomically to file:/opt/spark/spark-checkpoint/commits/0 using temp file file:/opt/spark/spark-checkpoint/commits/.0.dbfbebf1-0c34-4c8b-be47-89190e50fbbc.tmp
# 25/05/22 13:32:17 INFO  CheckpointFileManager:60 Renamed temp file file:/opt/spark/spark-checkpoint/commits/.0.dbfbebf1-0c34-4c8b-be47-89190e50fbbc.tmp to file:/opt/spark/spark-checkpoint/commits/0
# 25/05/22 13:32:17 INFO  MicroBatchExecution:60 Streaming query made progress: {
#   "id" : "917d27d6-db61-44ba-9bf3-c07d7bcbc499",
#   "runId" : "182ce788-ca28-48a2-b2b5-1c5eea8b2279",
#   "name" : null,
#   "timestamp" : "2025-05-22T13:32:14.742Z",
#   "batchId" : 0,
#   "numInputRows" : 1,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.3755163349605708,
#   "durationMs" : {
#     "addBatch" : 2090,
#     "commitOffsets" : 69,
#     "getBatch" : 134,
#     "latestOffset" : 106,
#     "queryPlanning" : 156,
#     "triggerExecution" : 2662,
#     "walCommit" : 78
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/opt/spark/datasets/devices/*.json]",
#     "startOffset" : null,
#     "endOffset" : {
#       "logOffset" : 0
#     },
#     "latestOffset" : null,
#     "numInputRows" : 1,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.3755163349605708
#   } ],
#   "sink" : {
#     "description" : "FileSink[/opt/spark/datasets/output/device_data.csv]",
#     "numOutputRows" : -1
#   }
# }
# 25/05/22 13:32:17 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:17 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:17 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:17 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:17 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:17 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:17 INFO  InMemoryFileIndex:60 It took 6 ms to list leaf files for 1 paths.
# 25/05/22 13:32:17 INFO  InMemoryFileIndex:60 It took 6 ms to list leaf files for 1 paths.
# 25/05/22 13:32:17 INFO  InMemoryFileIndex:60 It took 6 ms to list leaf files for 1 paths.
# 25/05/22 13:32:17 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:17 INFO  InMemoryFileIndex:60 It took 6 ms to list leaf files for 1 paths.
# 25/05/22 13:32:17 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:17 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:17 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:17 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:17 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:17 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 6 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 6 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 6 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 6 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:18 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 6 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 6 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:19 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:20 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 6 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 6 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:21 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 7 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 7 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:22 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 6 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 3 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:23 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 3 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  BlockManagerInfo:60 Removed broadcast_3_piece0 on 6af08edc54fe:42885 in memory (size: 80.1 KiB, free: 434.4 MiB)
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 9 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  BlockManagerInfo:60 Removed broadcast_3_piece0 on 172.18.0.11:33849 in memory (size: 80.1 KiB, free: 1048.8 MiB)
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 3 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 3 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 6 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 3 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:24 INFO  InMemoryFileIndex:60 It took 8 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 3 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 3 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:25 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 6 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 6 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 7 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 6 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:26 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 3 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  MicroBatchExecution:60 Streaming query has been idle and waiting for new data more than 10000 ms.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 3 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 3 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 3 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 3 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:27 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 6 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:28 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:29 INFO  InMemoryFileIndex:60 It took 4 ms to list leaf files for 1 paths.
# 25/05/22 13:32:29 INFO  InMemoryFileIndex:60 It took 3 ms to list leaf files for 1 paths.
# 25/05/22 13:32:29 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:29 INFO  InMemoryFileIndex:60 It took 6 ms to list leaf files for 1 paths.
# 25/05/22 13:32:29 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# 25/05/22 13:32:29 INFO  InMemoryFileIndex:60 It took 6 ms to list leaf files for 1 paths.
# 25/05/22 13:32:29 INFO  InMemoryFileIndex:60 It took 5 ms to list leaf files for 1 paths.
# ...
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:55 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:56 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/opt/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/socket.py", line 720, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:57 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 10
#       1 # Write the output to console sink to check the output
#       3 (flattened_df
#       4  .writeStream
#       5  .format("csv")
#       6  .outputMode("append")
#       7  .option("path", "/opt/spark/datasets/output/device_data.csv")
#       8  .option("checkpointLocation", "/opt/spark/spark-checkpoint")
#       9  .start()
# ---> 10  .awaitTermination())
#
# File /opt/spark/python/pyspark/sql/streaming/query.py:221, in StreamingQuery.awaitTermination(self, timeout)
#     219     return self._jsq.awaitTermination(int(timeout * 1000))
#     220 else:
# --> 221     return self._jsq.awaitTermination()
#
# File /opt/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1314 args_command, temp_args = self._build_args(*args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# -> 1321 answer = self.gateway_client.send_command(command)
#    1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#
# File /opt/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1036 connection = self._get_connection()
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#    1040         return response, self._create_connection_guard(connection)
#
# File /opt/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py:511, in ClientServerConnection.send_command(self, command)
#     509 try:
#     510     while True:
# --> 511         answer = smart_decode(self.stream.readline()[:-1])
#     512         logger.debug("Answer received: {0}".format(answer))
#     513         # Happens when a the other end is dead. There might be an empty
#     514         # answer before the socket raises an error.
#
# File /usr/local/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# KeyboardInterrupt:
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.

# %%
# Check the data at the output location
# Out:
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:58 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:34:59 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
# 25/05/22 13:35:00 INFO  InMemoryFileIndex:60 It took 0 ms to list leaf files for 0 paths.
